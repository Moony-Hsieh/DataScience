# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %% [markdown]
# # 前言
# 建立：2019/06/16
# 在整理資料的過程
# 學習怎麼用更快更簡便的方式
# 將資料讀入的筆記
#
# 最一開始是一個檔案一個檔案讀入
# 當檔案變多的時候
# 覺得也太多行code了
#
# 爬文看有沒有更簡便的方式
# 以下是我整理的筆記
#
# 1. Pandas read_csv
# 2. glob
# 3. os.walk

# %% [markdown]
# ## 使用環境

# %%
# !conda -V
# Out:
# conda 4.6.14

# %%
# !python --version
# Out:
# Python 3.6.6 :: Anaconda custom (64-bit)

# %% [markdown]
# # 資料來源
# 這邊使用的資料為氣象局的資料
# 觀測資料查詢系統
# https://e-service.cwb.gov.tw/HistoryDataQuery/index.jsp
#
# 我的目的是要整理台北的氣象資料
# 後續當作建模的feature
#
# 取三個測站資料的平均來代表台北地區
# 松山 Songshan (C0AH70)
# 臺北 TAIPEI (466920)
# 信義 Xinyi (C0AC70)

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 50)

# %% [markdown]
# # Input Data

# %% [markdown]
# ## Pandas read_csv
# 這是我最一開始接觸資料的讀取方式
#
# PS:資料只有抓到2019/06/13
# 但是csv是整個月的表格
# 沒有資料的部分會捨棄
# 所以只有2019/06
# 資料只會取前13筆
# t_weather1906.iloc[:13]

# %%
# 檔案路徑
# 資料只到20190613
t_path = '1reference/天氣/466920臺北/'
s_path = '1reference/天氣/C0AH70松山/'
x_path = '1reference/天氣/C0AC70信義/'

t_weather1806 = pd.read_csv(t_path + '466920-2018-06.csv')
t_weather1807 = pd.read_csv(t_path + '466920-2018-07.csv')
t_weather1808 = pd.read_csv(t_path + '466920-2018-08.csv')
t_weather1809 = pd.read_csv(t_path + '466920-2018-09.csv')
t_weather1810 = pd.read_csv(t_path + '466920-2018-10.csv')
t_weather1811 = pd.read_csv(t_path + '466920-2018-11.csv')
t_weather1812 = pd.read_csv(t_path + '466920-2018-12.csv')
t_weather1901 = pd.read_csv(t_path + '466920-2019-01.csv')
t_weather1902 = pd.read_csv(t_path + '466920-2019-02.csv')
t_weather1903 = pd.read_csv(t_path + '466920-2019-03.csv')
t_weather1904 = pd.read_csv(t_path + '466920-2019-04.csv')
t_weather1905 = pd.read_csv(t_path + '466920-2019-05.csv')
t_weather1906 = pd.read_csv(t_path + '466920-2019-06.csv')

t_weather = pd.concat([t_weather1806,t_weather1807,t_weather1808,t_weather1809,t_weather1810,
                       t_weather1811,t_weather1812,t_weather1901,t_weather1902,t_weather1903,
                      t_weather1904,t_weather1905,t_weather1906.iloc[:13]])

# s_weather06 = pd.read_csv(s_path + 'C0AH70-2018-06.csv')
# s_weather07 = pd.read_csv(s_path + 'C0AH70-2018-07.csv')
# s_weather08 = pd.read_csv(s_path + 'C0AH70-2018-08.csv')
# s_weather09 = pd.read_csv(s_path + 'C0AH70-2018-09.csv')
# s_weather10 = pd.read_csv(s_path + 'C0AH70-2018-10.csv')
# s_weather11 = pd.read_csv(s_path + 'C0AH70-2018-11.csv')
# s_weather12 = pd.read_csv(s_path + 'C0AH70-2018-12.csv')
# s_weather13 = pd.read_csv(s_path + 'C0AH70-2019-01.csv')
# s_weather14 = pd.read_csv(s_path + 'C0AH70-2019-02.csv')
# s_weather15 = pd.read_csv(s_path + 'C0AH70-2019-03.csv')

# s_weather = pd.concat([s_weather06,s_weather07,s_weather08,s_weather09,s_weather10,
#                        s_weather11,s_weather12,s_weather13,s_weather14,s_weather15.iloc[:22]])

# x_weather06 = pd.read_csv(x_path + 'C0AC70-2018-06.csv')
# x_weather07 = pd.read_csv(x_path + 'C0AC70-2018-07.csv')
# x_weather08 = pd.read_csv(x_path + 'C0AC70-2018-08.csv')
# x_weather09 = pd.read_csv(x_path + 'C0AC70-2018-09.csv')
# x_weather10 = pd.read_csv(x_path + 'C0AC70-2018-10.csv')
# x_weather11 = pd.read_csv(x_path + 'C0AC70-2018-11.csv')
# x_weather12 = pd.read_csv(x_path + 'C0AC70-2018-12.csv')
# x_weather13 = pd.read_csv(x_path + 'C0AC70-2019-01.csv')
# x_weather14 = pd.read_csv(x_path + 'C0AC70-2019-02.csv') 
# x_weather15 = pd.read_csv(x_path + 'C0AC70-2019-03.csv') 

# x_weather = pd.concat([x_weather06,x_weather07,x_weather08,x_weather09,x_weather10,x_weather11,
#                        x_weather12,x_weather13,x_weather14,x_weather15.iloc[:22]])

# %%
t_weather.head()
# Out:
#    ObsTime StnPres SeaPres StnPresMax    StnPresMaxTime StnPresMin  \
# 0        1  1008.8  1012.3     1010.2  2018-06-01 21:48     1006.7
# 1        2  1008.2  1011.7     1009.7  2018-06-02 08:21     1006.9
# 2        3  1005.8  1009.3     1007.2  2018-06-03 07:05     1004.1
# 3        4  1005.5    1009       1007  2018-06-04 22:10     1003.9
# 4        5  1005.7  1009.2     1007.6  2018-06-05 21:28       1004
#
#      StnPresMinTime Temperature T Max        T Max Time T Min  \
# 0  2018-06-01 01:58        24.7  27.6  2018-06-01 00:01  22.2
# 1  2018-06-02 16:24        25.2    28  2018-06-02 12:51  22.9
# 2  2018-06-03 16:22        27.2  31.8  2018-06-03 10:18  25.2
# 3  2018-06-04 14:03        28.6    36  2018-06-04 11:53  25.5
# 4  2018-06-05 15:52        29.8  37.4  2018-06-05 12:25  25.7
#
#          T Min Time Td dew point  RH RHMin         RHMinTime   WS  WD WSGust  \
# 0  2018-06-01 21:01         19.3  72    65  2018-06-01 15:19  4.3  80   14.3
# ...

# %% [markdown]
# ### 備註
# 由於覺得上面太多code，懶得一個個打
# 所以開始爬文尋找替代方案

# %% [markdown]
# ## Glob

# %% [markdown]
# 簡單掌握Python中glob模組查詢檔案路徑的用法 | 程式前沿
# https://codertw.com/%E7%A8%8B%E5%BC%8F%E8%AA%9E%E8%A8%80/368441/
# 基本用法
# 1.glob.glob（pathname), 返回所有匹配的檔案路徑列表。它只有一個引數pathname，定義了檔案路徑匹配規則，這裡可以是絕對路徑，也可以是相對路徑。
# 2.glob.iglob(pathname), 獲取一個可編歷物件，使用它可以逐個獲取匹配的檔案路徑名。與glob.glob()的區別是：glob.glob同時獲取所有的匹配路徑，  而glob.iglob一次只獲取一個匹配路徑。
# 萬用字元
# 星號匹配一個檔名段中的0個或多個字元。
# 單位元組萬用字元
# 問號會匹配檔名中該位置的單個字元。
# 字元區間
# 使用字元區間([a-z])，可以匹配多個字元中的一個字元。

# %% [markdown]
# python - Import multiple csv files into pandas and concatenate into one DataFrame - Stack Overflow
# https://stackoverflow.com/questions/20906474/import-multiple-csv-files-into-pandas-and-concatenate-into-one-dataframe
# import pandas as pd
# import glob
#
# path = r'C:\DRO\DCL_rawdata_files' # use your path
# all_files = glob.glob(path + "/*.csv")
#
# li = []
#
# for filename in all_files:
#     df = pd.read_csv(filename, index_col=None, header=0)
#     li.append(df)
#
# frame = pd.concat(li, axis=0, ignore_index=True)

# %%
import glob

# 資料只到20190613
t_path = '1reference/天氣/466920臺北/'

t_list = []

for filename in glob.glob(t_path + "/*.csv"):
    df = pd.read_csv(filename)
    t_list.append(df)
t_weather = pd.concat(t_list, axis=0, ignore_index=True)

# %%
t_weather.head()
# Out:
#    ObsTime StnPres SeaPres StnPresMax    StnPresMaxTime StnPresMin  \
# 0        1   999.8  1003.2     1001.4  2018-08-01 07:39      997.5
# 1        2   998.7    1002     1000.3  2018-08-02 07:54      996.3
# 2        3   999.9  1003.4     1002.1  2018-08-03 21:31      998.2
# 3        4  1001.9  1005.4     1003.3  2018-08-04 23:17     1000.2
# 4        5  1002.6  1006.1     1004.4  2018-08-05 07:21     1000.7
#
#      StnPresMinTime Temperature T Max        T Max Time T Min  \
# 0  2018-08-01 16:39        32.1    37  2018-08-01 12:55  29.1
# 1  2018-08-02 16:01        32.3  37.2  2018-08-02 13:44  29.2
# 2  2018-08-03 01:51        29.8  36.5  2018-08-03 11:40  25.6
# 3  2018-08-04 17:24        29.6  35.6  2018-08-04 11:34  26.3
# 4  2018-08-05 16:40        30.9  36.2  2018-08-05 13:04  27.6
#
#          T Min Time Td dew point  RH RHMin         RHMinTime   WS   WD WSGust  \
# 0  2018-08-01 04:39         24.2  64    44  2018-08-01 13:21  1.8  280    9.8
# ...

# %% [markdown]
# ### 備註
# 實驗還蠻成功的，學到新的方式
# 不過發現讀入的時候，順序是亂的
#
# 另外，想要找找
# 之前看過別人用os.walk

# %% [markdown]
# ## OS walk

# %% [markdown]
# Python 列出目錄中所有檔案教學：os.listdir 與 os.walk - G. T. Wang
# https://blog.gtwang.org/programming/python-list-all-files-in-directory/
# * os.listdir 可以取得指定目錄中所有的檔案與子目錄名稱

# %%
import os
path_weather = '1reference/天氣/'
os.listdir(path_weather)
# Out:
# ['466920臺北', '.DS_Store', 'C0AH70松山', 'C0AC70信義']

# %% [markdown]
# Python 列出目錄中所有檔案教學：os.listdir 與 os.walk - G. T. Wang
# https://blog.gtwang.org/programming/python-list-all-files-in-directory/
# from os import walk
#
# 指定要列出所有檔案的目錄
# mypath = "/var/log"
#
# 遞迴列出所有子目錄與檔案
# for root, dirs, files in walk(mypath):
#   print("路徑：", root)
#   print("  目錄：", dirs)
#   print("  檔案：", files)
# * os.walk 會自動遞迴搜尋指定路徑之下的所有子目錄，將每一個目錄中的檔案都列出來，並且自動區分檔案與目錄

# %%
import os
path_weather = '1reference/天氣/'

for root, dirs, files in os.walk(path_weather):
    print("路徑：", root)
    print("  目錄：", dirs)
    print("  檔案：", files)
# Out:
# 路徑： 1reference/天氣/
#   目錄： ['466920臺北', 'C0AH70松山', 'C0AC70信義']
#   檔案： ['.DS_Store']
# 路徑： 1reference/天氣/466920臺北
#   目錄： []
#   檔案： ['466920-2018-08.csv', '466920-2018-09.csv', '466920-2019-03.csv', '466920-2019-02.csv', '466920-2019-01.csv', '466920-2019-05.csv', '466920-2019-04.csv', '466920-2019-06.csv', '466920-2018-07.csv', '466920-2018-12.csv', '466920-2018-06.csv', '466920-2018-10.csv', '466920-2018-11.csv']
# 路徑： 1reference/天氣/C0AH70松山
#   目錄： []
#   檔案： ['C0AH70-2018-08.csv', 'C0AH70-2018-09.csv', 'C0AH70-2019-01.csv', 'C0AH70-2019-03.csv', 'C0AH70-2019-02.csv', 'C0AH70-2019-06.csv', 'C0AH70-2019-05.csv', 'C0AH70-2019-04.csv', 'C0AH70-2018-10.csv', 'C0AH70-2018-11.csv', 'C0AH70-2018-07.csv', 'C0AH70-2018-12.csv', 'C0AH70-2018-06.csv']
# 路徑： 1reference/天氣/C0AC70信義
#   目錄： []
# ...

# %% [markdown]
# * 嘗試os.path.join

# %%
import os
path_weather = '1reference/天氣/'
# files = os.listdir(path_weather)
# ['466920臺北', '.DS_Store', 'C0AH70松山', 'C0AC70信義']

for root, dirs, files in os.walk(path_weather):
    print("路徑：", root)
    print("  目錄：", dirs)
    print("  檔案：", files)
    for f in files:
        print(os.path.join(root,f))
# Out:
# 路徑： 1reference/天氣/
#   目錄： ['466920臺北', 'C0AH70松山', 'C0AC70信義']
#   檔案： ['.DS_Store']
# 1reference/天氣/.DS_Store
# 路徑： 1reference/天氣/466920臺北
#   目錄： []
#   檔案： ['466920-2018-08.csv', '466920-2018-09.csv', '466920-2019-03.csv', '466920-2019-02.csv', '466920-2019-01.csv', '466920-2019-05.csv', '466920-2019-04.csv', '466920-2019-06.csv', '466920-2018-07.csv', '466920-2018-12.csv', '466920-2018-06.csv', '466920-2018-10.csv', '466920-2018-11.csv']
# 1reference/天氣/466920臺北/466920-2018-08.csv
# 1reference/天氣/466920臺北/466920-2018-09.csv
# 1reference/天氣/466920臺北/466920-2019-03.csv
# 1reference/天氣/466920臺北/466920-2019-02.csv
# 1reference/天氣/466920臺北/466920-2019-01.csv
# 1reference/天氣/466920臺北/466920-2019-05.csv
# 1reference/天氣/466920臺北/466920-2019-04.csv
# 1reference/天氣/466920臺北/466920-2019-06.csv
# 1reference/天氣/466920臺北/466920-2018-07.csv
# 1reference/天氣/466920臺北/466920-2018-12.csv
# 1reference/天氣/466920臺北/466920-2018-06.csv
# 1reference/天氣/466920臺北/466920-2018-10.csv
# ...

# %% [markdown]
# Python讀取指定文件夾下的文件 - IT閱讀
# https://www.itread01.com/content/1533797912.html
# import csv
# import os
# import pandas as pd
# 提取文件夾下的地址+文件名，源文件設定排序規則
# def file_name(file_dir):
#      L = []
#      for root, dirs, files in os.walk(file_dir):
#          for file in files:
#              if os.path.splitext(file)[1] == ‘.csv‘:
#                  L.append(os.path.join(root , file))
#          return L
#  print(file_name(‘C:/Users/夏爾/Desktop‘))

# %%
l=[]
for root, dirs, files in os.walk(path_weather):
    for f in files:
        if os.path.splitext(f)[1] == '.csv':
            l.append(os.path.join(root,f))

# %%
l
# Out:
# ['1reference/天氣/466920臺北/466920-2018-08.csv',
#  '1reference/天氣/466920臺北/466920-2018-09.csv',
#  '1reference/天氣/466920臺北/466920-2019-03.csv',
#  '1reference/天氣/466920臺北/466920-2019-02.csv',
#  '1reference/天氣/466920臺北/466920-2019-01.csv',
#  '1reference/天氣/466920臺北/466920-2019-05.csv',
#  '1reference/天氣/466920臺北/466920-2019-04.csv',
#  '1reference/天氣/466920臺北/466920-2019-06.csv',
#  '1reference/天氣/466920臺北/466920-2018-07.csv',
#  '1reference/天氣/466920臺北/466920-2018-12.csv',
#  '1reference/天氣/466920臺北/466920-2018-06.csv',
#  '1reference/天氣/466920臺北/466920-2018-10.csv',
#  '1reference/天氣/466920臺北/466920-2018-11.csv',
#  '1reference/天氣/C0AH70松山/C0AH70-2018-08.csv',
#  '1reference/天氣/C0AH70松山/C0AH70-2018-09.csv',
#  '1reference/天氣/C0AH70松山/C0AH70-2019-01.csv',
#  '1reference/天氣/C0AH70松山/C0AH70-2019-03.csv',
#  '1reference/天氣/C0AH70松山/C0AH70-2019-02.csv',
#  '1reference/天氣/C0AH70松山/C0AH70-2019-06.csv',
#  '1reference/天氣/C0AH70松山/C0AH70-2019-05.csv',
# ...

# %% [markdown]
# * 試想只擷取其中一個測站的資料
#
# Does Python have a string 'contains' substring method? - Stack Overflow
# https://stackoverflow.com/questions/3437059/does-python-have-a-string-contains-substring-method
# Does Python have a string contains substring method?
# Yes, but Python has a comparison operator that you should use instead, because the language intends its usage, and other programmers will expect you to use it. That keyword is in, which is used as a comparison operator

# %%
t=[]
for root, dirs, files in os.walk(path_weather):
    if '臺北' in root:
        for f in files:
            if os.path.splitext(f)[1] == '.csv':
                t.append(os.path.join(root,f))

# %%
t
# Out:
# ['1reference/天氣/466920臺北/466920-2018-08.csv',
#  '1reference/天氣/466920臺北/466920-2018-09.csv',
#  '1reference/天氣/466920臺北/466920-2019-03.csv',
#  '1reference/天氣/466920臺北/466920-2019-02.csv',
#  '1reference/天氣/466920臺北/466920-2019-01.csv',
#  '1reference/天氣/466920臺北/466920-2019-05.csv',
#  '1reference/天氣/466920臺北/466920-2019-04.csv',
#  '1reference/天氣/466920臺北/466920-2019-06.csv',
#  '1reference/天氣/466920臺北/466920-2018-07.csv',
#  '1reference/天氣/466920臺北/466920-2018-12.csv',
#  '1reference/天氣/466920臺北/466920-2018-06.csv',
#  '1reference/天氣/466920臺北/466920-2018-10.csv',
#  '1reference/天氣/466920臺北/466920-2018-11.csv']

# %%
import os
path_weather = '1reference/天氣/'

t=[]
s=[]
x=[]

for root, dirs, files in os.walk(path_weather):
    if '臺北' in root:
        for f in files:
            if os.path.splitext(f)[1] == '.csv':
                t_df = pd.read_csv(os.path.join(root,f))
                t.append(t_df)
    elif '松山' in root:
        for f in files:
            if os.path.splitext(f)[1] == '.csv':
                s_df = pd.read_csv(os.path.join(root,f))
                s.append(s_df)
    elif '信義' in root:
        for f in files:
            if os.path.splitext(f)[1] == '.csv':
                x_df = pd.read_csv(os.path.join(root,f))
                x.append(x_df)      
                
t_weather = pd.concat(t, axis=0, ignore_index=True)
s_weather = pd.concat(s, axis=0, ignore_index=True)
x_weather = pd.concat(x, axis=0, ignore_index=True)

# %%
t_weather.head()
# Out:
#    ObsTime StnPres SeaPres StnPresMax    StnPresMaxTime StnPresMin  \
# 0        1   999.8  1003.2     1001.4  2018-08-01 07:39      997.5
# 1        2   998.7    1002     1000.3  2018-08-02 07:54      996.3
# 2        3   999.9  1003.4     1002.1  2018-08-03 21:31      998.2
# 3        4  1001.9  1005.4     1003.3  2018-08-04 23:17     1000.2
# 4        5  1002.6  1006.1     1004.4  2018-08-05 07:21     1000.7
#
#      StnPresMinTime Temperature T Max        T Max Time T Min  \
# 0  2018-08-01 16:39        32.1    37  2018-08-01 12:55  29.1
# 1  2018-08-02 16:01        32.3  37.2  2018-08-02 13:44  29.2
# 2  2018-08-03 01:51        29.8  36.5  2018-08-03 11:40  25.6
# 3  2018-08-04 17:24        29.6  35.6  2018-08-04 11:34  26.3
# 4  2018-08-05 16:40        30.9  36.2  2018-08-05 13:04  27.6
#
#          T Min Time Td dew point  RH RHMin         RHMinTime   WS   WD WSGust  \
# 0  2018-08-01 04:39         24.2  64    44  2018-08-01 13:21  1.8  280    9.8
# ...

# %% [markdown]
# # Input Data by File Name Order
# 以上嘗試都很不錯
# 但我還是想要檔案能夠依序讀入
#
# 會有這個需求也是因為
# 資料本身的結構
#
# 本來，在合併完資料之後
# 我會把2019/06/13之後的日期給drop掉
#
# 這可以很方便尋找

# %%
t_weather[t_weather['StnPresMaxTime']=='...']
# Out:
#      ObsTime StnPres SeaPres StnPresMax StnPresMaxTime StnPresMin  \
# 225       14     ...     ...        ...            ...        ...
# 226       15     ...     ...        ...            ...        ...
# 227       16     ...     ...        ...            ...        ...
# 228       17     ...     ...        ...            ...        ...
# 229       18     ...     ...        ...            ...        ...
# 230       19     ...     ...        ...            ...        ...
# 231       20     ...     ...        ...            ...        ...
# 232       21     ...     ...        ...            ...        ...
# 233       22     ...     ...        ...            ...        ...
# 234       23     ...     ...        ...            ...        ...
# 235       24     ...     ...        ...            ...        ...
# 236       25     ...     ...        ...            ...        ...
# 237       26     ...     ...        ...            ...        ...
# ...

# %%
t_weather.tail()
# Out:
#      ObsTime StnPres SeaPres StnPresMax    StnPresMaxTime StnPresMin  \
# 390       26  1015.4    1019       1017  2018-11-26 22:11     1014.2
# 391       27  1016.2  1019.8     1017.6  2018-11-27 09:16     1014.5
# 392       28  1016.7  1020.3     1019.1  2018-11-28 22:05     1014.4
# 393       29  1018.7  1022.3     1020.9  2018-11-29 09:43     1017.2
# 394       30  1016.8  1020.4     1019.1  2018-11-30 07:38     1014.5
#
#        StnPresMinTime Temperature T Max        T Max Time T Min  \
# 390  2018-11-26 01:51          21  23.6  2018-11-26 12:14  19.3
# 391  2018-11-27 13:21          21  22.4  2018-11-27 13:26  19.8
# 392  2018-11-28 15:24          20  21.1  2018-11-28 10:43  18.9
# 393  2018-11-29 14:58        20.9    24  2018-11-29 13:08  19.4
# 394  2018-11-30 13:59        22.7    27  2018-11-30 13:23  19.7
#
#            T Min Time Td dew point  RH RHMin         RHMinTime   WS   WD  \
# 390  2018-11-26 04:35         17.2  79    62  2018-11-26 12:03  1.5  140
# ...

# %% [markdown]
# 不過可以看到的是
# dataframe是依照filename清單合併的
# 第一順位是2018-08
# 最後一個順位是2018-11
#
# 在t_weather看起來還好
# 可以直接針對序號
# 將缺失值drop
# 只要列出日期有缺失值的欄位，再drop掉就好

# %%
t_weather[t_weather['StnPresMaxTime']=='...'].index
# Out:
# Int64Index([225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237,
#             238, 239, 240, 241],
#            dtype='int64')

# %%
t_weather.drop([225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241],inplace=True)

# %% [markdown]
# 不過後續在處理其他測站資料
# x_weather就有發現到狀況

# %%
x_weather[x_weather['StnPresMaxTime']=='...']
# Out:
#      ObsTime StnPres SeaPres StnPresMax StnPresMaxTime StnPresMin  \
# 378       14     ...     ...        ...            ...        ...
# 379       15     ...     ...        ...            ...        ...
# 380       16     ...     ...        ...            ...        ...
# 381       17     ...     ...        ...            ...        ...
# 382       18     ...     ...        ...            ...        ...
# 383       19     ...     ...        ...            ...        ...
# 384       20     ...     ...        ...            ...        ...
# 385       21     ...     ...        ...            ...        ...
# 386       22     ...     ...        ...            ...        ...
# 387       23     ...     ...        ...            ...        ...
# 388       24     ...     ...        ...            ...        ...
# 389       25     ...     ...        ...            ...        ...
# 390       26     ...     ...        ...            ...        ...
# ...

# %% [markdown]
# 2019/06/13之後的日期
# 也是可以簡單處理
# 但是到後面
# 檢查缺失值的時候

# %%
drop_columns = ['SeaPres', 'StnPresMax', 'StnPresMin',
            'Td dew point', 'RHMin', 'RHMinTime', 'WD', 'WSGust', 'WDGust', 'WGustTime', 
            'PrecpHour', 'PrecpMax10', 'PrecpMax10Time', 'PrecpHrMax', 'PrecpHrMaxTime',
            'SunShine', 'SunShineRate', 'GloblRad', 'VisbMean', 'EvapA', 'UVI Max', 'UVI Max Time', 'Cloud Amount']
x_weather = x_weather.drop(drop_columns,axis = 1)
x_weather[x_weather.isna().any(1)]
# Out:
#      ObsTime StnPres StnPresMaxTime StnPresMinTime Temperature T Max  \
# 31         1  1004.4            NaN            NaN        23.6   ...
# 67         7  1014.3            NaN            NaN        17.7   ...
# 84        24  1012.3            NaN            NaN        16.5   ...
# 118       27  1012.2            NaN            NaN        22.1   ...
# 151       29  1014.4            NaN            NaN        20.1   ...
# 227       14  1011.7            NaN            NaN        20.7   ...
# 228       15  1014.7            NaN            NaN        16.9   ...
# 234       21  1003.1            NaN            NaN        25.7   ...
# 249        5  1009.2            NaN            NaN        17.7   ...
# 250        6  1006.9            NaN            NaN        20.1   ...
# 279        7  1013.1            NaN            NaN        19.8   ...
# 285       13  1012.8            NaN            NaN        17.5   ...
# 304        1  1002.7            NaN            NaN        20.9   ...
# ...

# %% [markdown]
# StnPresMaxTime欄位
# 是我主要當作日期的欄位
# 這個欄位有缺失值
# 基本上後續就不能排序了
#
# 不過資料上
# 本來就是一個月一份資料
# 所以依照檔案名稱讀入順序
# 沒有日期也是可以做處理的

# %% [markdown]
# ## Sorted()
# 可以用sorted()來排序檔名
# Analyzing Data from Multiple Files – Programming with Python
# https://swcarpentry.github.io/python-novice-inflammation/04-files/
# glob.glob’s result is a list of file and directory paths in arbitrary order.
# If we want to start by analyzing just the first three files in alphabetical order, we can use the sorted built-in function to generate a new sorted list from the glob.glob output

# %%
t=[]
for root, dirs, files in os.walk(path_weather):
    if '臺北' in root:
        for f in files:
            if os.path.splitext(f)[1] == '.csv':
                t.append(os.path.join(root,f))

# %%
t
# Out:
# ['1reference/天氣/466920臺北/466920-2018-08.csv',
#  '1reference/天氣/466920臺北/466920-2018-09.csv',
#  '1reference/天氣/466920臺北/466920-2019-03.csv',
#  '1reference/天氣/466920臺北/466920-2019-02.csv',
#  '1reference/天氣/466920臺北/466920-2019-01.csv',
#  '1reference/天氣/466920臺北/466920-2019-05.csv',
#  '1reference/天氣/466920臺北/466920-2019-04.csv',
#  '1reference/天氣/466920臺北/466920-2019-06.csv',
#  '1reference/天氣/466920臺北/466920-2018-07.csv',
#  '1reference/天氣/466920臺北/466920-2018-12.csv',
#  '1reference/天氣/466920臺北/466920-2018-06.csv',
#  '1reference/天氣/466920臺北/466920-2018-10.csv',
#  '1reference/天氣/466920臺北/466920-2018-11.csv']

# %%
sorted(t)
# Out:
# ['1reference/天氣/466920臺北/466920-2018-06.csv',
#  '1reference/天氣/466920臺北/466920-2018-07.csv',
#  '1reference/天氣/466920臺北/466920-2018-08.csv',
#  '1reference/天氣/466920臺北/466920-2018-09.csv',
#  '1reference/天氣/466920臺北/466920-2018-10.csv',
#  '1reference/天氣/466920臺北/466920-2018-11.csv',
#  '1reference/天氣/466920臺北/466920-2018-12.csv',
#  '1reference/天氣/466920臺北/466920-2019-01.csv',
#  '1reference/天氣/466920臺北/466920-2019-02.csv',
#  '1reference/天氣/466920臺北/466920-2019-03.csv',
#  '1reference/天氣/466920臺北/466920-2019-04.csv',
#  '1reference/天氣/466920臺北/466920-2019-05.csv',
#  '1reference/天氣/466920臺北/466920-2019-06.csv']

# %%
t[0]
# Out:
# '1reference/天氣/466920臺北/466920-2018-08.csv'

# %%
t[0][:t[0].rfind('.')]
# Out:
# '1reference/天氣/466920臺北/466920-2018-08'

# %%
sorted(t)[0]
# Out:
# '1reference/天氣/466920臺北/466920-2018-06.csv'

# %% [markdown]
# * 改變code，可以依照檔名順序，將dataframe給concat起來

# %%
t=[]
for root, dirs, files in os.walk(path_weather):
    if '臺北' in root:
        for f in files:
            if os.path.splitext(f)[1] == '.csv':
                t.append(os.path.join(root,f))

t_sort=[]
for i in sorted(t):
    df = pd.read_csv(i)
    t_sort.append(df)

# %%
t_sort[-1].head()
# Out:
#    ObsTime StnPres SeaPres StnPresMax    StnPresMaxTime StnPresMin  \
# 0        1  1004.2  1007.7     1006.1  2019-06-01 00:03     1002.0
# 1        2  1002.1  1005.5     1004.3  2019-06-02 23:58     1000.2
# 2        3  1003.6  1007.1     1005.1  2019-06-03 22:07     1002.4
# 3        4  1005.4  1008.9     1007.3  2019-06-04 10:36     1003.6
# 4        5  1007.1  1010.5     1008.2  2019-06-05 22:25     1005.8
#
#      StnPresMinTime Temperature T Max        T Max Time T Min  \
# 0  2019-06-01 14:41        27.1  32.3  2019-06-01 12:08  25.6
# 1  2019-06-02 15:39        30.0  36.6  2019-06-02 12:02  25.7
# 2  2019-06-03 15:05        28.4  31.3  2019-06-03 10:59  25.9
# 3  2019-06-04 02:05        27.8  30.0  2019-06-04 17:09  26.2
# 4  2019-06-05 02:58        29.3  34.4  2019-06-05 13:07  25.7
#
#          T Min Time Td dew point  RH RHMin         RHMinTime   WS   WD WSGust  \
# 0  2019-06-01 03:53         24.0  84    53  2019-06-01 12:13  1.3  120    8.3
# ...

# %% [markdown]
# ## Order by File Name
# 前面想到的是，先把檔名排序再讀入
# 這邊想到的是
# 可以在每個dataframe，新增一個filename的欄位
# 然後再依照filename來排序row
# 好像更簡單一點(code上不用兩個for loop)

# %% [markdown]
# 爬文找靈感
# Working with many files in pandas
# http://jonathansoma.com/lede/foundations-2017/classes/working-with-many-files/class/
# zip loops through TWO THINGS AT ONCE
# so you're looking at dataframe #1 and filename #1
# then dataframe #2 and filename #2
# etc
# and assigning that filename as a new column in the dataframe
# for dataframe, filename in zip(list_of_dfs, filenames)
#   dataframe['filename'] = filename

# %% [markdown]
# 將檔名儲存在for loop階段
# pandas - Python to append multiple csv files and add column with file names? - Stack Overflow
# https://stackoverflow.com/questions/54172932/python-to-append-multiple-csv-files-and-add-column-with-file-names
# The following should work by creating the filename column before appending the dataframe to your list.
# file_list = list()
#
# for file in os.listdir():
#     if file.endswith('.csv'):
#         df = pd.read_csv(file)
#         df['filename'] = file
#         file_list.append(df)
#
# all_days = pd.concat(file_list, axis=0, ignore_index=True)

# %%
t=[]
for root, dirs, files in os.walk(path_weather):
    if '臺北' in root:
        for filename in files:
            if os.path.splitext(filename)[1] == '.csv':
                df = pd.read_csv(os.path.join(root,filename))
                df['filename'] = filename
                t.append(df)
t_concat = pd.concat(t,ignore_index=True)

# %%
t_concat.loc[:,'filename'].head()
# Out:
# 0    466920-2018-08.csv
# 1    466920-2018-08.csv
# 2    466920-2018-08.csv
# 3    466920-2018-08.csv
# 4    466920-2018-08.csv
# Name: filename, dtype: object

# %% [markdown]
# 發現到檔名是存全名
# 檔名是.csv，想把副檔名去掉不要存
# split - Python: Cut off the last word of a sentence? - Stack Overflow
# https://stackoverflow.com/questions/6266727/python-cut-off-the-last-word-of-a-sentence
# 方法一：rsplit
# You can split you text by last space symbol into two parts using rsplit.
# text = 'Python: Cut of the last word of a sentence?'
# text.rsplit(' ', 1)[0]
# 'Python: Cut of the last word of a'
# rsplit is a shorthand for "reverse split", and unlike regular split works from the end of a string. The second parameter is a maximum number of splits to make - e.g. value of 1 will give you two-element list as a result (since there was a single split made, which resulted in two pieces of the input string).
# With some of the other answers if feel it is necessary to note that rsplit is reverse split (not regex split) and the 1 is maxsplit.
#
# 方法二：rfind
# Get last index of space and splice the string
# text = 'Python: Cut of the last word of a sentence?'
# text[:text.rfind(' ')]
# 'Python: Cut of the last word of a'
# This one is 15-20% faster on small strings than the accepted answer.
#
# 查找什麼是rfind
# Python String rfind() Method
# https://www.w3schools.com/python/ref_string_rfind.asp
# The rfind() method finds the last occurrence of the specified value.

# %%
# 實驗看看：
t=[]
for root, dirs, files in os.walk(path_weather):
    if '臺北' in root:
        for f in files:
            if os.path.splitext(f)[1] == '.csv':
                t.append(os.path.join(root,f))
t[0]
# Out:
# '1reference/天氣/466920臺北/466920-2018-08.csv'

# %%
# 成果還不錯
t[0][:t[0].rfind('.')]
# Out:
# '1reference/天氣/466920臺北/466920-2018-08'

# %%
# 修改code，結果可以依照檔案名稱將dataframe排序：
t=[]
for root, dirs, files in os.walk(path_weather):
    if '臺北' in root:
        for filename in files:
            #只選結尾是副檔名'.csv'
            if os.path.splitext(filename)[1] == '.csv':
                #依照檔名路徑存成dataframe
                df = pd.read_csv(os.path.join(root,filename))
                #在dataframe新增欄位filename，用來儲存檔名
                #rfind那樣可以把'.'後面的csv去掉
                df['filename'] = filename[:filename.rfind('.')]
                t.append(df)
t_concat = pd.concat(t,ignore_index=True)
#如果只依照檔名排序，可能會把每個csv裡面的日期打亂
#ObsTime就是代表每個月的幾號
#類似說，檔名(年月)+ObsTime(日)，來排序
t_concat.sort_values(['filename','ObsTime']).head()
# Out:
#      ObsTime StnPres SeaPres StnPresMax    StnPresMaxTime StnPresMin  \
# 304        1  1008.8  1012.3     1010.2  2018-06-01 21:48     1006.7
# 305        2  1008.2  1011.7     1009.7  2018-06-02 08:21     1006.9
# 306        3  1005.8  1009.3     1007.2  2018-06-03 07:05     1004.1
# 307        4  1005.5    1009       1007  2018-06-04 22:10     1003.9
# 308        5  1005.7  1009.2     1007.6  2018-06-05 21:28       1004
#
#        StnPresMinTime Temperature T Max        T Max Time T Min  \
# 304  2018-06-01 01:58        24.7  27.6  2018-06-01 00:01  22.2
# 305  2018-06-02 16:24        25.2    28  2018-06-02 12:51  22.9
# 306  2018-06-03 16:22        27.2  31.8  2018-06-03 10:18  25.2
# 307  2018-06-04 14:03        28.6    36  2018-06-04 11:53  25.5
# 308  2018-06-05 15:52        29.8  37.4  2018-06-05 12:25  25.7
#
#            T Min Time Td dew point  RH RHMin         RHMinTime   WS  WD  \
# 304  2018-06-01 21:01         19.3  72    65  2018-06-01 15:19  4.3  80
# ...

# %% [markdown]
# # 其他資源
#
# 💻 How to iterate over files in directory python
# https://www.newbedev.com/python/howto/how-to-iterate-over-files-in-a-given-directory/
# Using os.listdir()
# Using os.walk()
# Using glob module
# Iterate recursively using Path class from pathlib module

# %% [markdown]
# 覺得寫成一行很厲害
# python - Read multiple .csv files from folder with variable part fo file name - Stack Overflow
# https://stackoverflow.com/questions/51844425/read-multiple-csv-files-from-folder-with-variable-part-fo-file-name
# df = pd.concat([pd.read_csv(f) for f in glob.glob('my_file*.csv')])

# %%
#可以將整個Notebook轉成html來開啟來看，並且有sidebar目錄
# !jupyter nbconvert --to html_toc 'Data_Input(multiple csv).ipynb'
# Out:
# [NbConvertApp] Converting notebook Data_Input(multiple csv).ipynb to html_toc
# [NbConvertApp] Writing 419770 bytes to Data_Input(multiple csv).html
